# %%
from queries import get_loc_desc

# %%
loc_descs = get_loc_desc()
loc_desc_options = ""
for desc in loc_descs.iterrows():
    loc_desc_options = loc_desc_options + "<option value='{}'>{}</option>\n".format(desc, desc)

# %%
loc_desc_options = ""
for desc in loc_descs["loc_desc"]:
    if desc == None: continue
    loc_desc_options = loc_desc_options + "<option value='{}'>{}</option>\n".format(desc, desc.lower())
print(loc_desc_options)
# Out:
# <option value='ABANDONED BUILDING'>abandoned building</option>
# <option value='AIRPORT/AIRCRAFT'>airport/aircraft</option>
# <option value='ALLEY'>alley</option>
# <option value='ANIMAL HOSPITAL'>animal hospital</option>
# <option value='APARTMENT'>apartment</option>
# <option value='APPLIANCE STORE'>appliance store</option>
# <option value='ATHLETIC CLUB'>athletic club</option>
# <option value='ATM (AUTOMATIC TELLER MACHINE)'>atm (automatic teller machine)</option>
# <option value='AUTO'>auto</option>
# <option value='BANK'>bank</option>
# <option value='BARBERSHOP'>barbershop</option>
# <option value='BAR/TAVERN/LIQUOR STORE'>bar/tavern/liquor store</option>
# <option value='BOWLING ALLEY'>bowling alley</option>
# <option value='BRIDGE'>bridge</option>
# <option value='CAR WASH'>car wash</option>
# <option value='CEMETARY'>cemetary</option>
# <option value='CHA APARTMENT'>cha apartment</option>
# ...

# %%
loc_descs
# Out:
#                              loc_desc
# 0                  ABANDONED BUILDING
# 1                    AIRPORT/AIRCRAFT
# 2                               ALLEY
# 3                     ANIMAL HOSPITAL
# 4                           APARTMENT
# 5                     APPLIANCE STORE
# 6                       ATHLETIC CLUB
# 7      ATM (AUTOMATIC TELLER MACHINE)
# 8                                AUTO
# 9                                BANK
# 10                         BARBERSHOP
# 11            BAR/TAVERN/LIQUOR STORE
# 12                      BOWLING ALLEY
# 13                             BRIDGE
# 14                           CAR WASH
# 15                           CEMETARY
# 16                      CHA APARTMENT
# 17     CHA HALLWAY/STAIRWELL/ELEVATOR
# 18            CHA PARKING LOT/GROUNDS
# 19  CHURCH/SYNAGOGUE/PLACE OF WORSHIP
# 20                     CLEANING STORE
# 21              COIN OPERATED MACHINE
# 22         COLLEGE/UNIVERSITY GROUNDS
# 23  COLLEGE/UNIVERSITY RESIDENCE HALL
# ...

# %%
str.
